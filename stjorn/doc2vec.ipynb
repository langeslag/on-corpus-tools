# %% [markdown]
# # Doc2Vec
#
# TF-IDF is limited by exact spelling. If our orthography is not too unpredictable, or else if our corpus is sufficiently large to gather it into patterns, perhaps word embeddings, scaled up to document embeddings, can offer a deeper insight into document similarity by learning about the similar contexts of different terms.

# %%
import os,glob,json,multiprocessing
import pandas as pd
import numpy as np
from gensim.models.doc2vec import TaggedDocument,Doc2Vec
from gensim.utils import simple_preprocess
from sklearn.metrics.pairwise import cosine_similarity

# %%
def normalize(target):
    # This dict limits orthographical variation beyond the rule sets
    # of stjorn-extract.ipynb and menota-extract.ipynb:
    matrix = {
        'j': 'i',
        'v': 'u',
        # For embeddings we may be better off keeping the d-ð distinction:
        #'ð': 'þ',
        'ð': 'd',
        'þ': 'd',
        'á': 'a',
        'ǽ': 'æ',
        'ę': 'æ',
        'é': 'e',
        'í': 'i',
        'ó': 'o',
        'ú': 'u',
        'ý': 'y',
        'ǿ': 'ø',
        'k': 'c', # rather than vice versa, because of Latin (e.g. Lucifer)
        '[': '',
        ']': ''
        }
    for k,v in matrix.items():
        target = target.replace(k, v)
    return target

titles = ['prologue', 'introduction', 'gn', 'ex', 'lv', 'nm', 'dt', 'ios', 'idc', 'rt', '1sm', '2sm', '3rg', '4rg']
tokens = []
for title in titles:
    with open(f"nlp/{title}.txt") as raw:
        document = normalize(raw.read().replace('\n', ' '))
        tokens.extend(document.split())

work_indices = {
    'stjorn1': (650,124417),
    'stjorn2': (124417,147678),
    'stjorn3': (147678,156943,160719),
    'stjorn4': (156943,160719)
}

stjorn = dict()
for _work, _range in work_indices.items():
    if len(_range) == 2:
        stjorn[_work] = (tokens[_range[0]:_range[1]])
    else:
        stjorn[_work] = tokens[_range[0]:_range[1]] + tokens[_range[2]:]

menota = dict()
for text in glob.glob('../menota/dipl/*txt'):
    ref = os.path.basename(text).replace('.txt', '')
    with open(text) as doc:
        # We'll subject Menota to the same normalization standard as Stjórn:
        menota[ref] = normalize(doc.read().replace('\n', '')).split()

num_cores = multiprocessing.cpu_count()

# %%
data = stjorn | menota
tagged_data = [TaggedDocument(words=v, tags=[k]) for k,v in data.items()]
model = Doc2Vec(
    vector_size=20, 
    min_count=2, 
    epochs=50, 
    workers=num_cores, 
    dm=1,               # DM is more context-sensitive, PV-DBOW is more efficient
    dbow_words=0)
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
for work in work_indices.keys():
    inferred_vector = model.infer_vector(data[work])
    sims = model.dv.most_similar([inferred_vector], topn=36)
    print(f"{work}:")
    print("------------------------")
    for i in sims[1:]:
        print(f"{i[0]}    {str(round(i[1], 5))}")
    print("\n")
# Out:
# stjorn1:
# ------------------------
# nraNorrFragm60A_stjorn    0.86706
# nraNorrFragm58B_konungs_skuggsja    0.78795
# nraNorrFragm79_mariu_saga    0.70608
# nraNorrFragm66_thomass_saga    0.70143
# nraNorrFragm80_pals_saga    0.68697
# stjorn4    0.68555
# nraNorrFragm78_mariu_saga    0.65351
# nraNorrFragm67_thomass_saga    0.65231
# stjorn2    0.64601
# am383I_thorlaks_saga    0.63137
# nraNorrFragm59_rimbegla    0.60485
# nraNorrFragm60C_stjorn    0.60119
# nraNorrFragm77_dialogar    0.58918
# stjorn3    0.57158
# nraNorrFragm75_kross_saga    0.56235
# nraNorrFragm71_gregors_saga_pafa    0.56202
# nraNorrFragm63_karlamagnuss_saga    0.53433
# nraNorrFragm72x76_dialogar    0.50511
# nraNorrFragm57_jons_saga_helga    0.49262
# holmPerg17_thomass_saga    0.49109
# nraNorrFragm69_nikulass_saga    0.49066
# nraNorrFragm64_barlaams_saga    0.47487
# nraNorrFragm55A_hakonar_saga    0.42853
# nraNorrFragm62_karlamagnuss_saga    0.42285
# holmPerg6_barlaams_saga    0.41972
# nraNorrFragm54_sverris_saga    0.41771
# am178_thidreks_saga    0.4131
# am132_finnboga_saga    0.40709
# am162bkappa_njals_saga    0.38932
# am132_laxdoela_saga    0.38795
# nks235g_konungs_skuggsja    0.38779
# am1056IX_konungs_skuggsja_fragment    0.3867
# am132_fostbraedra_saga    0.38425
# nraNorrFragm70_agotu_saga    0.38189
# nraNorrFragm58A_konungs_skuggsja    0.3687
#
#
# stjorn2:
# ------------------------
# nraNorrFragm58B_konungs_skuggsja    0.75024
# stjorn4    0.71916
# nraNorrFragm80_pals_saga    0.65193
# nraNorrFragm59_rimbegla    0.64417
# am162bkappa_njals_saga    0.62515
# stjorn1    0.62434
# nraNorrFragm60A_stjorn    0.58046
# nraNorrFragm62_karlamagnuss_saga    0.57456
# am162balpha_njals_saga    0.55798
# nraNorrFragm60C_stjorn    0.54698
# am178_thidreks_saga    0.53586
# nraNorrFragm63_karlamagnuss_saga    0.53086
# holmPerg34_boejarlog    0.52568
# nraNorrFragm79_mariu_saga    0.52398
# nraNorrFragm60B_stjorn    0.49774
# stjorn3    0.48911
# am132_finnboga_saga    0.46681
# holmPerg34_landslog    0.46099
# nraNorrFragm75_kross_saga    0.44909
# am132_njals_saga    0.43952
# nraNorrFragm68_brendanuss_saga    0.43684
# am132_hallfredar_saga    0.4249
# holmPerg6_barlaams_saga    0.41443
# am132_olkofra_thattr    0.40473
# am655_laeknisbok    0.40169
# am132_viga-glums_saga    0.39959
# am132_bandamanna_saga    0.39766
# am132_fostbraedra_saga    0.3914
# am132_droplaugasona_saga    0.39096
# nraNorrFragm77_dialogar    0.38791
# nraNorrFragm70_agotu_saga    0.38074
# nraNorrFragm78_mariu_saga    0.37515
# nraNorrFragm66_thomass_saga    0.36947
# nraNorrFragm67_thomass_saga    0.36595
# am162btheta_njals_saga    0.36039
#
#
# stjorn3:
# ------------------------
# stjorn4    0.91353
# nraNorrFragm60C_stjorn    0.75657
# nraNorrFragm62_karlamagnuss_saga    0.74323
# nraNorrFragm57_jons_saga_helga    0.72708
# nraNorrFragm63_karlamagnuss_saga    0.72652
# nraNorrFragm80_pals_saga    0.71885
# nraNorrFragm67_thomass_saga    0.66155
# nraNorrFragm79_mariu_saga    0.6595
# nraNorrFragm54_sverris_saga    0.64686
# nraNorrFragm61_karlamagnuss_saga    0.62221
# nraNorrFragm64_barlaams_saga    0.608
# nraNorrFragm75_kross_saga    0.59377
# nraNorrFragm58B_konungs_skuggsja    0.58545
# nraNorrFragm60A_stjorn    0.58205
# nraNorrFragm66_thomass_saga    0.58017
# nraNorrFragm55B_hakonar_saga    0.57741
# nraNorrFragm78_mariu_saga    0.57612
# nraNorrFragm60B_stjorn    0.5687
# nraNorrFragm77_dialogar    0.56662
# stjorn1    0.56576
# nraNorrFragm68_brendanuss_saga    0.55691
# nraNorrFragm71_gregors_saga_pafa    0.53348
# stjorn2    0.5313
# am544_voluspa    0.51081
# nraNorrFragm55A_hakonar_saga    0.48878
# nraNorrFragm59_rimbegla    0.48008
# dg4-7_pamphilius_saga    0.47
# dg4-7_eliss_saga    0.46997
# gks2365_voluspa    0.44706
# am132_fostbraedra_saga    0.42543
# am162btheta_njals_saga    0.41265
# nraNorrFragm72x76_dialogar    0.40238
# am63_heimskringla3    0.40203
# nraNorrFragm69_nikulass_saga    0.39302
# am519a_alexanders_saga    0.38746
#
#
# stjorn4:
# ------------------------
# stjorn3    0.90422
# nraNorrFragm62_karlamagnuss_saga    0.82409
# nraNorrFragm60C_stjorn    0.81121
# nraNorrFragm63_karlamagnuss_saga    0.79462
# nraNorrFragm80_pals_saga    0.75054
# stjorn2    0.74733
# nraNorrFragm54_sverris_saga    0.70885
# nraNorrFragm58B_konungs_skuggsja    0.6873
# stjorn1    0.67177
# nraNorrFragm57_jons_saga_helga    0.65351
# nraNorrFragm79_mariu_saga    0.65058
# nraNorrFragm60A_stjorn    0.63991
# nraNorrFragm55B_hakonar_saga    0.63691
# nraNorrFragm67_thomass_saga    0.63552
# nraNorrFragm68_brendanuss_saga    0.61732
# nraNorrFragm55A_hakonar_saga    0.61679
# nraNorrFragm60B_stjorn    0.6142
# nraNorrFragm61_karlamagnuss_saga    0.614
# nraNorrFragm59_rimbegla    0.60637
# nraNorrFragm75_kross_saga    0.59743
# nraNorrFragm78_mariu_saga    0.58639
# nraNorrFragm77_dialogar    0.5515
# nraNorrFragm66_thomass_saga    0.54403
# am162bkappa_njals_saga    0.52933
# nraNorrFragm71_gregors_saga_pafa    0.5278
# am544_voluspa    0.50902
# nraNorrFragm64_barlaams_saga    0.50529
# am162balpha_njals_saga    0.48058
# nraNorrFragm56_thorgils_saga    0.46081
# nraNorrFragm69_nikulass_saga    0.44968
# am242_codex_wormianus    0.44967
# am178_thidreks_saga    0.44048
# gks2365_voluspa    0.41837
# wolfAug9-10_egils_saga    0.41328
# am162btheta_njals_saga    0.40485

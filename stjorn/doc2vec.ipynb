# %% [markdown]
# # Doc2Vec: _Stjórn_ Document Embeddings
#
# TF-IDF is limited by exact spelling. If our orthography is not too unpredictable, or else if our corpus is sufficiently large to gather it into patterns, perhaps word embeddings, scaled up to document embeddings, can offer a deeper insight into document similarity by learning about the similar contexts of different terms.

# %%
import os,glob,multiprocessing,matplotlib
from gensim.models.doc2vec import TaggedDocument,Doc2Vec
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text
from sklearn.decomposition import PCA

# %%
def normalize(target):
    # This dict limits orthographical variation beyond the rule sets
    # of stjorn-extract.ipynb and menota-extract.ipynb:
    matrix = {
        'j': 'i',
        'v': 'u',
        # For embeddings we may be better off keeping the d-ð distinction:
        #'ð': 'þ',
        'ð': 'd',
        'þ': 'd',
        'á': 'a',
        'ǽ': 'æ',
        'ę': 'æ',
        'é': 'e',
        'í': 'i',
        'ó': 'o',
        'ú': 'u',
        'ý': 'y',
        'ǿ': 'ø',
        'k': 'c', # rather than vice versa, because of Latin (e.g. Lucifer)
        '[': '',
        ']': ''
        }
    for k,v in matrix.items():
        target = target.replace(k, v)
    return target

titles = ['prologue', 'introduction', 'gn', 'ex', 'lv', 'nm', 'dt', 'ios', 'idc', 'rt', '1sm', '2sm', '3rg', '4rg']
tokens = []
for title in titles:
    with open(f"nlp/{title}.txt") as raw:
        document = normalize(raw.read().replace('\n', ' '))
        tokens.extend(document.split())

work_indices = {
    'stjorn1': (650,124417),
    'stjorn2': (124417,147678),
    'stjorn3': (147678,156943,160719),
    'stjorn4': (156943,160719)
}

stjorn = dict()
for _work, _range in work_indices.items():
    if len(_range) == 2:
        stjorn[_work] = (tokens[_range[0]:_range[1]])
    else:
        stjorn[_work] = tokens[_range[0]:_range[1]] + tokens[_range[2]:]

menota = dict()
for text in glob.glob('../menota/dipl/*txt'):
    ref = os.path.basename(text).replace('.txt', '')
    with open(text) as doc:
        # We'll subject Menota to the same normalization standard as Stjórn:
        menota[ref] = normalize(doc.read().replace('\n', '')).split()

num_cores = multiprocessing.cpu_count()

# %%
data = stjorn | menota
tagged_data = [TaggedDocument(words=v, tags=[k]) for k,v in data.items()]
model = Doc2Vec(
    vector_size=20, 
    min_count=2, 
    epochs=50, 
    workers=num_cores, 
    dm=1,               # DM is more context-sensitive, PV-DBOW is more efficient;
    dbow_words=0)       # experiment with both, but expect better results with dm=1
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
def rankings(doc_list):
    if type(doc_list) == str:
        doc_list = [doc_list]
    for work in doc_list:
        inferred_vector = model.infer_vector(data[work])
        sims = model.dv.most_similar([inferred_vector], topn=36)
        print(f"{work}:")
        print("------------------------")
        for i in sims[1:]:
            print(f"{i[0]}    {str(round(i[1], 5))}")
        print("\n")

# %%
rankings(work_indices.keys())
# Out:
# stjorn1:
# ------------------------
# nraNorrFragm60A_stjorn    0.85577
# nraNorrFragm58B_konungs_skuggsja    0.79927
# nraNorrFragm79_mariu_saga    0.77308
# stjorn4    0.7134
# nraNorrFragm80_pals_saga    0.70922
# nraNorrFragm67_thomass_saga    0.6594
# stjorn3    0.64785
# nraNorrFragm66_thomass_saga    0.63658
# nraNorrFragm78_mariu_saga    0.62842
# nraNorrFragm71_gregors_saga_pafa    0.61962
# nraNorrFragm77_dialogar    0.60323
# nraNorrFragm75_kross_saga    0.60174
# nraNorrFragm60C_stjorn    0.57067
# am383I_thorlaks_saga    0.55094
# nraNorrFragm59_rimbegla    0.53658
# stjorn2    0.53112
# nraNorrFragm63_karlamagnuss_saga    0.50918
# nraNorrFragm69_nikulass_saga    0.49764
# nraNorrFragm64_barlaams_saga    0.49613
# nraNorrFragm72x76_dialogar    0.48582
# am242_codex_wormianus    0.46363
# holmPerg17_thomass_saga    0.45774
# nraNorrFragm58A_konungs_skuggsja    0.45488
# nraNorrFragm57_jons_saga_helga    0.44957
# nraNorrFragm54_sverris_saga    0.42876
# am132_laxdoela_saga    0.41718
# am655_laeknisbok    0.41669
# am243balpha_konungs_skuggsja    0.4116
# nraNorrFragm62_karlamagnuss_saga    0.40503
# dg4-7_pamphilius_saga    0.4
# holmPerg6_barlaams_saga    0.39117
# nraNorrFragm60B_stjorn    0.39106
# am544_voluspa    0.38938
# am1056IX_konungs_skuggsja_fragment    0.37848
# am132_bandamanna_saga    0.36911
#
#
# stjorn2:
# ------------------------
# nraNorrFragm58B_konungs_skuggsja    0.73145
# stjorn4    0.72201
# nraNorrFragm80_pals_saga    0.668
# nraNorrFragm59_rimbegla    0.63157
# am162bkappa_njals_saga    0.62888
# nraNorrFragm60A_stjorn    0.58659
# nraNorrFragm79_mariu_saga    0.56272
# stjorn3    0.55918
# am162btheta_njals_saga    0.55645
# am162balpha_njals_saga    0.55523
# nraNorrFragm68_brendanuss_saga    0.55002
# nraNorrFragm60B_stjorn    0.5423
# nraNorrFragm60C_stjorn    0.53063
# am132_viga-glums_saga    0.52688
# stjorn1    0.52135
# holmPerg34_boejarlog    0.51344
# nraNorrFragm77_dialogar    0.51176
# am677_gregory    0.49463
# am132_olkofra_thattr    0.48217
# nraNorrFragm75_kross_saga    0.47543
# nraNorrFragm62_karlamagnuss_saga    0.47199
# am132_droplaugasona_saga    0.46611
# holmPerg34_landslog    0.463
# am132_njals_saga    0.46285
# wolfAug9-10_egils_saga    0.44592
# am655_laeknisbok    0.44269
# nraNorrFragm67_thomass_saga    0.4191
# am178_thidreks_saga    0.41801
# am132_fostbraedra_saga    0.41798
# nraNorrFragm63_karlamagnuss_saga    0.41709
# holmPerg6_barlaams_saga    0.41164
# am132_bandamanna_saga    0.39088
# nraNorrFragm78_mariu_saga    0.38728
# nraNorrFragm72x76_dialogar    0.38659
# am619_norwegian_homily_book    0.38652
#
#
# stjorn3:
# ------------------------
# stjorn4    0.94301
# nraNorrFragm60C_stjorn    0.83194
# nraNorrFragm62_karlamagnuss_saga    0.77856
# nraNorrFragm67_thomass_saga    0.69063
# nraNorrFragm54_sverris_saga    0.67679
# nraNorrFragm63_karlamagnuss_saga    0.65979
# nraNorrFragm80_pals_saga    0.65171
# nraNorrFragm58B_konungs_skuggsja    0.64482
# stjorn1    0.6391
# nraNorrFragm61_karlamagnuss_saga    0.61677
# nraNorrFragm60A_stjorn    0.60607
# nraNorrFragm71_gregors_saga_pafa    0.59744
# nraNorrFragm78_mariu_saga    0.58454
# nraNorrFragm64_barlaams_saga    0.57842
# nraNorrFragm60B_stjorn    0.57299
# nraNorrFragm55B_hakonar_saga    0.57272
# stjorn2    0.5721
# nraNorrFragm57_jons_saga_helga    0.56728
# nraNorrFragm68_brendanuss_saga    0.56577
# wolfAug9-10_egils_saga    0.56467
# nraNorrFragm55A_hakonar_saga    0.55666
# nraNorrFragm79_mariu_saga    0.55442
# dg4-7_eliss_saga    0.48569
# nraNorrFragm66_thomass_saga    0.48052
# am132_egils_saga    0.4796
# nraNorrFragm75_kross_saga    0.47837
# nraNorrFragm69_nikulass_saga    0.45848
# am162btheta_njals_saga    0.44737
# nraNorrFragm59_rimbegla    0.44418
# am162bkappa_njals_saga    0.43497
# am63_heimskringla3    0.40053
# nraNorrFragm56_thorgils_saga    0.39406
# nraNorrFragm77_dialogar    0.39349
# am132_hallfredar_saga    0.37935
# dg4-7_pamphilius_saga    0.37691
#
#
# stjorn4:
# ------------------------
# stjorn3    0.9401
# nraNorrFragm60C_stjorn    0.78779
# nraNorrFragm62_karlamagnuss_saga    0.74889
# stjorn2    0.71642
# stjorn1    0.69879
# wolfAug9-10_egils_saga    0.68948
# nraNorrFragm58B_konungs_skuggsja    0.68727
# nraNorrFragm80_pals_saga    0.68721
# nraNorrFragm67_thomass_saga    0.64895
# nraNorrFragm60A_stjorn    0.64511
# nraNorrFragm63_karlamagnuss_saga    0.63718
# nraNorrFragm54_sverris_saga    0.63064
# nraNorrFragm60B_stjorn    0.58819
# nraNorrFragm55A_hakonar_saga    0.58535
# nraNorrFragm68_brendanuss_saga    0.57034
# nraNorrFragm71_gregors_saga_pafa    0.56109
# nraNorrFragm78_mariu_saga    0.56009
# am132_egils_saga    0.55874
# nraNorrFragm79_mariu_saga    0.55813
# nraNorrFragm55B_hakonar_saga    0.54394
# nraNorrFragm59_rimbegla    0.54149
# nraNorrFragm57_jons_saga_helga    0.53597
# am162bkappa_njals_saga    0.52477
# nraNorrFragm61_karlamagnuss_saga    0.50802
# am162btheta_njals_saga    0.50121
# am162balpha_njals_saga    0.50106
# nraNorrFragm69_nikulass_saga    0.49519
# nraNorrFragm75_kross_saga    0.48442
# nraNorrFragm64_barlaams_saga    0.4693
# nraNorrFragm66_thomass_saga    0.44262
# nraNorrFragm77_dialogar    0.44094
# nraNorrFragm56_thorgils_saga    0.42321
# am132_hallfredar_saga    0.41301
# am132_olkofra_thattr    0.41258
# am63_heimskringla3    0.39501

# %% [markdown]
# Given the TF-IDF similarity between `holmPerg17_thomass_saga` and _Stjórn I_, we may rank similarities for the former as well:

# %%
rankings('holmPerg17_thomass_saga')
# Out:
# holmPerg17_thomass_saga:
# ------------------------
# nraNorrFragm81B_benedikts_regla    0.78954
# nraNorrFragm66_thomass_saga    0.78472
# am1056IX_konungs_skuggsja_fragment    0.70838
# am519a_alexanders_saga    0.63885
# nraNorrFragm60A_stjorn    0.61564
# nraNorrFragm63_karlamagnuss_saga    0.57552
# dg4-7_strengleikar    0.55105
# dg4-7_pamphilius_saga    0.54474
# am242_codex_wormianus    0.5421
# am383I_thorlaks_saga    0.50473
# nks235g_konungs_skuggsja    0.4992
# nraNorrFragm61_karlamagnuss_saga    0.49781
# nraNorrFragm71_gregors_saga_pafa    0.49059
# am243balpha_konungs_skuggsja    0.47859
# nraNorrFragm75_kross_saga    0.45924
# nraNorrFragm79_mariu_saga    0.45816
# stjorn1    0.45528
# nraNorrFragm64_barlaams_saga    0.45404
# nraNorrFragm62_karlamagnuss_saga    0.44528
# dg4-7_eliss_saga    0.43598
# am279a_gragas    0.42832
# nraNorrFragm51_fagrskinna    0.41379
# nraNorrFragm81A_benedikts_regla    0.41171
# nraNorrFragm58B_konungs_skuggsja    0.40019
# nraNorrFragm78_mariu_saga    0.39989
# nraNorrFragm58A_konungs_skuggsja    0.39308
# am78_kristinrettir    0.37691
# nraNorrFragm67_thomass_saga    0.37632
# meII2_frostathingslog    0.37493
# am619_norwegian_homily_book    0.36949
# nraNorrFragm60C_stjorn    0.34552
# nraNorrFragm65_floress_saga    0.34241
# am132_finnboga_saga    0.34127
# am544_voluspa    0.33943
# am178_thidreks_saga    0.33868

# %%
model.wv.most_similar('medr')
# Out:
# [('iardarinnar', 0.7951724529266357),
#  ('auoxt', 0.7734484672546387),
#  ('læide', 0.7637181282043457),
#  ('himinsins', 0.7546219825744629),
#  ('salo', 0.7476146221160889),
#  ('auflgan', 0.7431989312171936),
#  ('craptanna', 0.741650402545929),
#  ('rundit', 0.7393562197685242),
#  ('nidra', 0.7376928925514221),
#  ('heidinni', 0.7373846173286438)]

# %%
model.wv.distance('medr', 'med')
# Out:
# 0.30245620012283325

# %%
model.wv.distance('medr', 'mædr')
# Out:
# 0.360872745513916

# %%
model.wv.distance('medr', 'mæd')
# Out:
# 0.3463210463523865

# %%
model.wv.distance('med', 'mæd')
# Out:
# 0.320570707321167

# %% [markdown]
# We can also use principal component analysis (PCA) to reduce the twenty dimensions of our Doc2Vec model to just two, so we can generate a scatter plot visualizing the documents' distribution across vector space:

# %%
colours = dict()
for i in data.keys():
    colours[i] = '#3CBDBD'
colours['stjorn1'] = '#264FA6'
colours['stjorn2'] = '#C27A13'
colours['stjorn3'] = '#355E26'
colours['stjorn4'] = '#ABA75B'
pca = PCA(n_components=2)
vectors = np.array([model.dv[i] for i in data.keys()])
pca_result = pca.fit_transform(vectors)
plt.figure(figsize=(15, 12))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=colours.values(), cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)
labels = [plt.annotate(txt, (pca_result[i, 0], pca_result[i, 1])) for i, txt in enumerate(data.keys())]
adjust_text(labels)
plt.title('PCA of Doc2Vec Matrix')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.savefig(fname='doc2vec.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4056/3944108067.py:13: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(pca_result[:, 0], pca_result[:, 1], c=colours.values(), cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)

# %% [markdown]
# # Doc2Vec: _Stjórn_ Document Embeddings
#
# TF-IDF is limited by exact spelling. If our orthography is not too unpredictable, or else if our corpus is sufficiently large to gather it into patterns, perhaps word embeddings, scaled up to document embeddings, can offer a deeper insight into document similarity by learning about the similar contexts of different terms.

# %%
import os,glob,multiprocessing
from gensim.models.doc2vec import TaggedDocument,Doc2Vec

# %%
def normalize(target):
    # This dict limits orthographical variation beyond the rule sets
    # of stjorn-extract.ipynb and menota-extract.ipynb:
    matrix = {
        'j': 'i',
        'v': 'u',
        # For embeddings we may be better off keeping the d-ð distinction:
        #'ð': 'þ',
        'ð': 'd',
        'þ': 'd',
        'á': 'a',
        'ǽ': 'æ',
        'ę': 'æ',
        'é': 'e',
        'í': 'i',
        'ó': 'o',
        'ú': 'u',
        'ý': 'y',
        'ǿ': 'ø',
        'k': 'c', # rather than vice versa, because of Latin (e.g. Lucifer)
        '[': '',
        ']': ''
        }
    for k,v in matrix.items():
        target = target.replace(k, v)
    return target

titles = ['prologue', 'introduction', 'gn', 'ex', 'lv', 'nm', 'dt', 'ios', 'idc', 'rt', '1sm', '2sm', '3rg', '4rg']
tokens = []
for title in titles:
    with open(f"nlp/{title}.txt") as raw:
        document = normalize(raw.read().replace('\n', ' '))
        tokens.extend(document.split())

work_indices = {
    'stjorn1': (650,124417),
    'stjorn2': (124417,147678),
    'stjorn3': (147678,156943,160719),
    'stjorn4': (156943,160719)
}

stjorn = dict()
for _work, _range in work_indices.items():
    if len(_range) == 2:
        stjorn[_work] = (tokens[_range[0]:_range[1]])
    else:
        stjorn[_work] = tokens[_range[0]:_range[1]] + tokens[_range[2]:]

menota = dict()
for text in glob.glob('../menota/dipl/*txt'):
    ref = os.path.basename(text).replace('.txt', '')
    with open(text) as doc:
        # We'll subject Menota to the same normalization standard as Stjórn:
        menota[ref] = normalize(doc.read().replace('\n', '')).split()

num_cores = multiprocessing.cpu_count()

# %%
data = stjorn | menota
tagged_data = [TaggedDocument(words=v, tags=[k]) for k,v in data.items()]
model = Doc2Vec(
    vector_size=20, 
    min_count=2, 
    epochs=50, 
    workers=num_cores, 
    dm=1,               # DM is more context-sensitive, PV-DBOW is more efficient
    dbow_words=0)
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
for work in work_indices.keys():
    inferred_vector = model.infer_vector(data[work])
    sims = model.dv.most_similar([inferred_vector], topn=36)
    print(f"{work}:")
    print("------------------------")
    for i in sims[1:]:
        print(f"{i[0]}    {str(round(i[1], 5))}")
    print("\n")
# Out:
# stjorn1:
# ------------------------
# nraNorrFragm60A_stjorn    0.84902
# nraNorrFragm58B_konungs_skuggsja    0.79376
# nraNorrFragm79_mariu_saga    0.75117
# stjorn4    0.71932
# nraNorrFragm67_thomass_saga    0.69907
# nraNorrFragm66_thomass_saga    0.6862
# nraNorrFragm80_pals_saga    0.66905
# nraNorrFragm77_dialogar    0.63867
# nraNorrFragm78_mariu_saga    0.62189
# stjorn3    0.60089
# nraNorrFragm71_gregors_saga_pafa    0.59295
# nraNorrFragm63_karlamagnuss_saga    0.59069
# nraNorrFragm75_kross_saga    0.58879
# nraNorrFragm59_rimbegla    0.5769
# am383I_thorlaks_saga    0.55727
# stjorn2    0.54937
# nraNorrFragm57_jons_saga_helga    0.5475
# nraNorrFragm60C_stjorn    0.546
# nraNorrFragm72x76_dialogar    0.50384
# nraNorrFragm69_nikulass_saga    0.49251
# holmPerg17_thomass_saga    0.48547
# am655_laeknisbok    0.48331
# nraNorrFragm62_karlamagnuss_saga    0.47613
# nraNorrFragm54_sverris_saga    0.45044
# nraNorrFragm60B_stjorn    0.42604
# am132_viga-glums_saga    0.4226
# am677_gregory    0.42006
# am242_codex_wormianus    0.41387
# nraNorrFragm64_barlaams_saga    0.40465
# nraNorrFragm58A_konungs_skuggsja    0.39505
# holmPerg6_barlaams_saga    0.39025
# am544_voluspa    0.38924
# nraNorrFragm68_brendanuss_saga    0.38892
# nraNorrFragm70_agotu_saga    0.38606
# am162bkappa_njals_saga    0.36633
#
#
# stjorn2:
# ------------------------
# stjorn4    0.73233
# nraNorrFragm58B_konungs_skuggsja    0.71744
# am162bkappa_njals_saga    0.68022
# nraNorrFragm60A_stjorn    0.62622
# nraNorrFragm80_pals_saga    0.59913
# nraNorrFragm59_rimbegla    0.57584
# am162balpha_njals_saga    0.55896
# stjorn1    0.54994
# am132_njals_saga    0.53927
# stjorn3    0.53367
# nraNorrFragm75_kross_saga    0.51641
# am162btheta_njals_saga    0.51622
# nraNorrFragm60C_stjorn    0.51459
# am132_fostbraedra_saga    0.51187
# am132_viga-glums_saga    0.51144
# am677_gregory    0.49012
# nraNorrFragm62_karlamagnuss_saga    0.48982
# nraNorrFragm60B_stjorn    0.48104
# nraNorrFragm68_brendanuss_saga    0.47474
# nraNorrFragm79_mariu_saga    0.47439
# nraNorrFragm77_dialogar    0.45938
# nraNorrFragm63_karlamagnuss_saga    0.45562
# am132_droplaugasona_saga    0.45454
# am132_olkofra_thattr    0.45193
# nraNorrFragm70_agotu_saga    0.44618
# nraNorrFragm67_thomass_saga    0.43176
# holmPerg34_boejarlog    0.42816
# holmPerg34_landslog    0.42665
# holmPerg6_barlaams_saga    0.42578
# nraNorrFragm69_nikulass_saga    0.40514
# nraNorrFragm78_mariu_saga    0.40373
# am178_thidreks_saga    0.40173
# am132_hallfredar_saga    0.39845
# nraNorrFragm72x76_dialogar    0.37698
# am132_finnboga_saga    0.37621
#
#
# stjorn3:
# ------------------------
# stjorn4    0.91232
# nraNorrFragm62_karlamagnuss_saga    0.74382
# nraNorrFragm60C_stjorn    0.68882
# nraNorrFragm58B_konungs_skuggsja    0.681
# nraNorrFragm60A_stjorn    0.62962
# nraNorrFragm63_karlamagnuss_saga    0.62747
# nraNorrFragm67_thomass_saga    0.61378
# stjorn1    0.60733
# nraNorrFragm79_mariu_saga    0.60726
# nraNorrFragm66_thomass_saga    0.6032
# nraNorrFragm64_barlaams_saga    0.57496
# nraNorrFragm80_pals_saga    0.57481
# stjorn2    0.57447
# nraNorrFragm60B_stjorn    0.55727
# nraNorrFragm75_kross_saga    0.55666
# am544_voluspa    0.54672
# nraNorrFragm59_rimbegla    0.54552
# nraNorrFragm54_sverris_saga    0.52923
# nraNorrFragm71_gregors_saga_pafa    0.52839
# nraNorrFragm57_jons_saga_helga    0.5189
# nraNorrFragm78_mariu_saga    0.50246
# dg4-7_eliss_saga    0.47678
# am519a_alexanders_saga    0.47569
# nraNorrFragm68_brendanuss_saga    0.46966
# nraNorrFragm61_karlamagnuss_saga    0.46929
# nraNorrFragm55B_hakonar_saga    0.44195
# nraNorrFragm77_dialogar    0.43668
# am178_thidreks_saga    0.43138
# holmPerg17_thomass_saga    0.42991
# gks2365_voluspa    0.42069
# am63_heimskringla3    0.41535
# wolfAug9-10_egils_saga    0.40804
# am242_codex_wormianus    0.40718
# dg4-7_pamphilius_saga    0.40383
# lbsFragm82_olafs_saga_helga    0.39823
#
#
# stjorn4:
# ------------------------
# stjorn3    0.89295
# stjorn2    0.75482
# nraNorrFragm62_karlamagnuss_saga    0.75376
# nraNorrFragm58B_konungs_skuggsja    0.73887
# nraNorrFragm60C_stjorn    0.72395
# stjorn1    0.71537
# nraNorrFragm60A_stjorn    0.70884
# nraNorrFragm63_karlamagnuss_saga    0.69115
# nraNorrFragm60B_stjorn    0.64842
# nraNorrFragm67_thomass_saga    0.62448
# nraNorrFragm59_rimbegla    0.61632
# nraNorrFragm80_pals_saga    0.61208
# nraNorrFragm79_mariu_saga    0.60292
# nraNorrFragm75_kross_saga    0.5987
# nraNorrFragm54_sverris_saga    0.59806
# nraNorrFragm68_brendanuss_saga    0.57391
# nraNorrFragm78_mariu_saga    0.56074
# nraNorrFragm66_thomass_saga    0.55834
# nraNorrFragm57_jons_saga_helga    0.55641
# am544_voluspa    0.54011
# nraNorrFragm55A_hakonar_saga    0.53967
# nraNorrFragm55B_hakonar_saga    0.53246
# nraNorrFragm71_gregors_saga_pafa    0.52773
# am162balpha_njals_saga    0.51305
# nraNorrFragm77_dialogar    0.50614
# am162bkappa_njals_saga    0.49422
# am178_thidreks_saga    0.48212
# nraNorrFragm64_barlaams_saga    0.46479
# am242_codex_wormianus    0.46085
# wolfAug9-10_egils_saga    0.46003
# nraNorrFragm61_karlamagnuss_saga    0.44221
# nraNorrFragm56_thorgils_saga    0.42951
# gks2365_voluspa    0.41601
# nraNorrFragm69_nikulass_saga    0.41211
# am162btheta_njals_saga    0.41198

# %%
model.wv.most_similar('medr')
# Out:
# [('rettlegha', 0.7925155162811279),
#  ('blæzadra', 0.7632014751434326),
#  ('auoxt', 0.7623628377914429),
#  ('gefum', 0.758270800113678),
#  ('ercibyscups', 0.7552791237831116),
#  ('med', 0.7520720958709717),
#  ('ualde', 0.747607946395874),
#  ('uinnatto', 0.7399964928627014),
#  ('blidlegha', 0.7399486899375916),
#  ('hormulega', 0.7330806851387024)]

# %%
model.wv.distance('medr', 'med')
# Out:
# 0.24792790412902832

# %%
model.wv.distance('medr', 'mædr')
# Out:
# 0.3852202892303467

# %%
model.wv.distance('medr', 'mæd')
# Out:
# 0.40650153160095215

# %%
model.wv.distance('med', 'mæd')
# Out:
# 0.3983585834503174

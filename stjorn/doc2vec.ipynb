# %% [markdown]
# # Doc2Vec: _Stjórn_ Document Embeddings
#
# TF-IDF is limited by exact spelling. If our orthography is not too unpredictable, or else if our corpus is sufficiently large to gather it into patterns, perhaps word embeddings, scaled up to document embeddings, can offer a deeper insight into document similarity by learning about the similar contexts of different terms.

# %%
import os,glob,multiprocessing,matplotlib
from gensim.models.doc2vec import TaggedDocument,Doc2Vec
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text
from sklearn.decomposition import PCA

# %%
def normalize(target):
    # This dict limits orthographical variation beyond the rule sets
    # of stjorn-extract.ipynb and menota-extract.ipynb:
    matrix = {
        'j': 'i',
        'v': 'u',
        '': 'u', # &vacute;
        # For embeddings we may be better off keeping the d-ð distinction:
        #'ð': 'þ',
        'ð': 'd',
        'þ': 'd',
        'á': 'a',
        'ǽ': 'æ',
        'ę': 'æ',
        'é': 'e',
        'í': 'i',
        'ó': 'o',
        '': 'ǫ', # &oogonacute;
        'ú': 'u',
        'ý': 'y',
        'ǿ': 'ø',
        'k': 'c', # rather than vice versa, because of Latin (e.g. Lucifer)
        '[': '',
        ']': ''
        }
    for k,v in matrix.items():
        target = target.replace(k, v)
    return target

titles = ['prologue', 'introduction', 'gn', 'ex', 'lv', 'nm', 'dt', 'ios', 'idc', 'rt', '1sm', '2sm', '3rg', '4rg']
tokens = []
for title in titles:
    with open(f"nlp/{title}.txt") as raw:
        document = normalize(raw.read().replace('\n', ' '))
        tokens.extend(document.split())

work_indices = {
    'stjorn1': (650,124417),
    'stjorn2': (124417,147678),
    'stjorn3': (147678,156943,160719),
    'stjorn4': (156943,160719)
}

stjorn = dict()
for _work, _range in work_indices.items():
    if len(_range) == 2:
        stjorn[_work] = (tokens[_range[0]:_range[1]])
    else:
        stjorn[_work] = tokens[_range[0]:_range[1]] + tokens[_range[2]:]

menota = dict()
#for text in glob.glob('../menota/am677-separated-out_dipl/*txt'):
for text in glob.glob('../menota/dipl/*txt'):
    ref = os.path.basename(text).replace('.txt', '')
    with open(text) as doc:
        # We'll subject Menota to the same normalization standard as Stjórn:
        menota[ref] = normalize(doc.read().replace('\n', '')).split()

num_cores = multiprocessing.cpu_count()

# %%
data = stjorn | menota
tagged_data = [TaggedDocument(words=v, tags=[k]) for k,v in data.items()]
model = Doc2Vec(
    vector_size=20, 
    min_count=2, 
    epochs=50, 
    workers=num_cores, 
    dm=1,               # DM is more context-sensitive, PV-DBOW is more efficient;
    dbow_words=0)       # experiment with both, but expect better results with dm=1
model.build_vocab(tagged_data)
model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
def rankings(doc_list):
    if type(doc_list) == str:
        doc_list = [doc_list]
    for work in doc_list:
        inferred_vector = model.infer_vector(data[work])
        sims = model.dv.most_similar([inferred_vector], topn=36)
        print(f"{work}:")
        print("------------------------")
        for i in sims[1:]:
            print(f"{i[0]}    {str(round(i[1], 5))}")
        print("\n")

# %%
rankings(work_indices.keys())
# Out:
# stjorn1:
# ------------------------
# nraNorrFragm60A_stjorn    0.81734
# nraNorrFragm58B_konungs_skuggsja    0.77316
# nraNorrFragm80_pals_saga    0.76745
# nraNorrFragm79_mariu_saga    0.72716
# nraNorrFragm67_thomass_saga    0.69229
# nraNorrFragm78_mariu_saga    0.67304
# nraNorrFragm77_dialogar    0.63814
# am383I_thorlaks_saga    0.63678
# nraNorrFragm66_thomass_saga    0.60923
# nraNorrFragm60C_stjorn    0.60745
# stjorn4    0.59868
# nraNorrFragm75_kross_saga    0.5985
# nraNorrFragm63_karlamagnuss_saga    0.58887
# nraNorrFragm71_gregors_saga_pafa    0.5636
# nraNorrFragm57_jons_saga_helga    0.55604
# stjorn2    0.54335
# nraNorrFragm72x76_dialogar    0.52536
# nraNorrFragm59_rimbegla    0.52397
# stjorn3    0.5065
# nraNorrFragm69_nikulass_saga    0.50322
# nraNorrFragm64_barlaams_saga    0.46873
# am677_gregory    0.46277
# nraNorrFragm62_karlamagnuss_saga    0.44786
# am132_hallfredar_saga    0.44082
# nraNorrFragm54_sverris_saga    0.42399
# ...

# %% [markdown]
# Given the TF-IDF similarity between `holmPerg17_thomass_saga` and _Stjórn I_, we may rank similarities for the former as well:

# %%
rankings('holmPerg17_thomass_saga')
# Out:
# holmPerg17_thomass_saga:
# ------------------------
# nraNorrFragm66_thomass_saga    0.78247
# nraNorrFragm81B_benedikts_regla    0.76866
# am1056IX_konungs_skuggsja_fragment    0.70389
# nraNorrFragm60A_stjorn    0.61637
# nraNorrFragm63_karlamagnuss_saga    0.58642
# am243balpha_konungs_skuggsja    0.55328
# nks235g_konungs_skuggsja    0.52573
# dg4-7_strengleikar    0.51583
# am519a_alexanders_saga    0.49346
# nraNorrFragm65_floress_saga    0.48523
# nraNorrFragm71_gregors_saga_pafa    0.48324
# nraNorrFragm78_mariu_saga    0.47962
# nraNorrFragm67_thomass_saga    0.46432
# nraNorrFragm61_karlamagnuss_saga    0.44871
# meII2_frostathingslog    0.43243
# am383I_thorlaks_saga    0.42981
# nraNorrFragm79_mariu_saga    0.42957
# nraNorrFragm64_barlaams_saga    0.42728
# stjorn1    0.4217
# am242_codex_wormianus    0.39767
# nraNorrFragm60C_stjorn    0.39297
# am178_thidreks_saga    0.39288
# nraNorrFragm72x76_dialogar    0.38986
# nraNorrFragm51_fagrskinna    0.38723
# ...

# %%
model.wv.most_similar('medr')
# Out:
# [('sidsæmdum', 0.8065046668052673),
#  ('med', 0.7840016484260559),
#  ('clerclegar', 0.7814574241638184),
#  ('natturu', 0.7663943767547607),
#  ('agætare', 0.7626829743385315),
#  ('æincannlegha', 0.762531042098999),
#  ('hǫgenda', 0.7539509534835815),
#  ('cuicendum', 0.7485986948013306),
#  ('dersarri', 0.7454730868339539),
#  ('reidardrumum', 0.7450743913650513)]

# %%
for idx, pair in enumerate([
    #('meþ', 'med'), 
    #('meþ', 'meþr'), 
    ('med', 'medr'), 
    #('medr', 'meþ'), 
    #('meþ', 'mæþ'), 
    #('med', 'mæþ'),
    ('med', 'mæd'),
    ('medr', 'mædr'),
    ('medr', 'mæd'),
    #('mæþ', 'mæþr'), 
    #('mædr', 'mæþr')
    ]):
    print(f"Distance between '{pair[0]}' and '{pair[1]}': {round(model.wv.distance(pair[0], pair[1]), 5)}")
# Out:
# Distance between 'med' and 'medr': 0.216
# Distance between 'med' and 'mæd': 0.32989
# Distance between 'medr' and 'mædr': 0.29821
# Distance between 'medr' and 'mæd': 0.34538

# %% [markdown]
# We can also use principal component analysis (PCA) to reduce the twenty dimensions of our Doc2Vec model to just two, so we can generate a scatter plot visualizing the documents' distribution across vector space:

# %%
colours = dict()
for i in data.keys():
    colours[i] = '#3CBDBD'
colours['stjorn1'] = '#264FA6'
colours['stjorn2'] = '#C27A13'
colours['stjorn3'] = '#355E26'
colours['stjorn4'] = '#ABA75B'
pca = PCA(n_components=2)
vectors = np.array([model.dv[i] for i in data.keys()])
pca_result = pca.fit_transform(vectors)
plt.figure(figsize=(15, 12))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=colours.values(), cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)
labels = [plt.annotate(txt, (pca_result[i, 0], pca_result[i, 1])) for i, txt in enumerate(data.keys())]
adjust_text(labels)
plt.title('2D PCA Scatter Plot of Doc2Vec Matrix')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
#plt.savefig(fname='doc2vec.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_537533/2648920624.py:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(pca_result[:, 0], pca_result[:, 1], c=colours.values(), cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)

# %%
pca3d = PCA(n_components=3)
vectors = np.array([model.dv[i] for i in data.keys()])
pca_result = pca3d.fit_transform(vectors)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(projection='3d')
x = pca_result[:, 0]
y = pca_result[:, 1]
z = pca_result[:, 2]
ax.set_title('3D PCA Scatter Plot of Doc2Vec Matrix', fontsize='12')
ax.set_xlabel('Principal component 1')
ax.set_ylabel('Principal component 2')
ax.set_zlabel('Principal component 3')
ax.view_init(elev=20, azim=310)
plt.tight_layout()
for i, txt in enumerate(data.keys()):
    ax.scatter(x[i],y[i],z[i], c=list(colours.values())[i], cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)
    ax.text(x[i],y[i],z[i], txt, fontsize=6)
#plt.savefig(fname='doc2vec3d.svg', format='svg', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_537533/1316388381.py:16: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(x[i],y[i],z[i], c=list(colours.values())[i], cmap=matplotlib.colors.ListedColormap(colours), edgecolor='k', s=50)
